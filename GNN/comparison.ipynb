# %%
import pandas as pd

df = pd.read_csv('GNN/results/training_results_summary_ToN.csv')
df2 = pd.read_csv('GNN/results/ddp_training_results_summary_ToN.csv')
df = pd.concat([df, df2])
df
# Out:
#    attack_cat  device  training_time_sec  accuracy  f1_malicious  \
# 0         dos    cuda              10.16   0.99931       0.99619
# 1        ddos    cuda               8.49   0.99910       0.99508
# 2    backdoor    cuda               8.42   0.99997       0.99981
# 3   injection    cuda               8.39   0.99919       0.99553
# 4    password    cuda               8.91   0.99953       0.99743
# 5  ransomware    cuda               8.46   0.99986       0.99924
# 6    scanning    cuda               8.40   0.99948       0.99715
# 7         xss    cuda               8.96   0.99945       0.99695
# 0         dos  cuda:2               9.59   0.99924       0.99578
# 1        ddos  cuda:2               4.73   0.99440       0.96989
# 2    backdoor  cuda:2               4.86   1.00000       1.00000
# 3   injection  cuda:2               4.87   0.99146       0.95280
# 4    password  cuda:2               4.97   0.99379       0.96578
# 5  ransomware  cuda:2               4.88   0.99976       0.99867
# 6    scanning  cuda:2               4.71   0.99962       0.99792
# 7         xss  cuda:2               4.89   0.99564       0.97571
#
#    precision_malicious  recall_malicious
# 0              0.99847           0.99392
# 1              0.99169           0.99848
# 2              1.00000           0.99962
# 3              0.99657           0.99449
# 4              0.99810           0.99677
# 5              0.99848           1.00000
# 6              0.99810           0.99620
# 7              0.99962           0.99430
# 0              0.99923           0.99235
# 1              0.95966           0.98034
# 2              1.00000           1.00000
# 3              0.95680           0.94882
# 4              0.95754           0.97416
# 5              0.99848           0.99886
# 6              0.99886           0.99698
# 7              0.99377           0.95830

# %%
df['accuracy'] = df['accuracy'] * 100
df['f1_malicious'] = df['f1_malicious'] * 100
df['precision_malicious'] = df['precision_malicious'] * 100
df['recall_malicious'] = df['recall_malicious'] * 100
df = df.sort_values(by=['attack_cat', 'device'], ascending=[True, True])
#reset index
df = df.reset_index(drop=True)
df
# Out:
#     attack_cat  device  training_time_sec  accuracy  f1_malicious  \
# 0     backdoor    cuda               8.42    99.997        99.981
# 1     backdoor  cuda:2               4.86   100.000       100.000
# 2         ddos    cuda               8.49    99.910        99.508
# 3         ddos  cuda:2               4.73    99.440        96.989
# 4          dos    cuda              10.16    99.931        99.619
# 5          dos  cuda:2               9.59    99.924        99.578
# 6    injection    cuda               8.39    99.919        99.553
# 7    injection  cuda:2               4.87    99.146        95.280
# 8     password    cuda               8.91    99.953        99.743
# 9     password  cuda:2               4.97    99.379        96.578
# 10  ransomware    cuda               8.46    99.986        99.924
# 11  ransomware  cuda:2               4.88    99.976        99.867
# 12    scanning    cuda               8.40    99.948        99.715
# 13    scanning  cuda:2               4.71    99.962        99.792
# 14         xss    cuda               8.96    99.945        99.695
# 15         xss  cuda:2               4.89    99.564        97.571
#
#     precision_malicious  recall_malicious
# 0               100.000            99.962
# 1               100.000           100.000
# 2                99.169            99.848
# 3                95.966            98.034
# 4                99.847            99.392
# 5                99.923            99.235
# 6                99.657            99.449
# 7                95.680            94.882
# 8                99.810            99.677
# 9                95.754            97.416
# 10               99.848           100.000
# 11               99.848            99.886
# 12               99.810            99.620
# 13               99.886            99.698
# 14               99.962            99.430
# 15               99.377            95.830

# %%
#salvo il dataframe
df.to_csv('GNN/results/report_completo_ToN_ddp.csv', index=False)

# %%
df_2 = pd.read_csv('/gpuserver/caputo/keep_calm/model_comparison_full_vs_cv.csv')
df_2
# Out:
#            Dataset          Model  Accuracy  Precision    Recall  F1 Score  \
# 0              dos  Random Forest  0.998939   0.987018  0.990752  0.988882
# 1              dos        Bagging  0.998859   0.986181  0.989912  0.988043
# 2              dos            SGD  0.995876   0.969330  0.943253  0.956114
# 3              dos       AdaBoost  0.998559   0.984868  0.984868  0.984868
# 4              dos    Naive Bayes  0.981502   0.725721  0.983186  0.835059
# 5          fuzzers  Random Forest  0.990045   0.842475  0.972855  0.902983
# 6          fuzzers        Bagging  0.990105   0.850207  0.961622  0.902489
# 7          fuzzers            SGD  0.988664   0.811798  0.991888  0.892852
# 8          fuzzers       AdaBoost  0.989080   0.817971  0.991264  0.896318
# 9          fuzzers    Naive Bayes  0.984236   0.751525  0.999376  0.857908
# 10        exploits  Random Forest  0.998677   0.983680  0.988619  0.986144
# 11        exploits        Bagging  0.998605   0.983494  0.987280  0.985384
# 12        exploits            SGD  0.994485   0.946124  0.937573  0.941829
# 13        exploits       AdaBoost  0.998095   0.981855  0.978075  0.979961
# 14        exploits    Naive Bayes  0.865287   0.260257  0.992636  0.412390
# 15         generic  Random Forest  0.999821   0.999552  0.998477  0.999014
# 16         generic        Bagging  0.999810   0.999402  0.998507  0.998954
# 17         generic            SGD  0.999096   0.998436  0.991608  0.995011
# 18         generic       AdaBoost  0.999674   0.999431  0.996984  0.998206
# 19         generic    Naive Bayes  0.997209   0.981716  0.987696  0.984697
# 20  reconnaissance  Random Forest  0.999593   0.996149  0.995297  0.995723
# 21  reconnaissance        Bagging  0.999552   0.996571  0.994015  0.995291
# 22  reconnaissance            SGD  0.995603   0.935934  0.974348  0.954755
# 23  reconnaissance       AdaBoost  0.999450   0.995287  0.993159  0.994222
# 24  reconnaissance    Naive Bayes  0.988334   0.803645  0.999145  0.890795
# 25        analysis  Random Forest  0.998864   0.976690  1.000000  0.988208
# 26        analysis        Bagging  0.998295   0.976415  0.988067  0.982206
# 27        analysis            SGD  0.998182   0.978622  0.983294  0.980952
# 28        analysis       AdaBoost  0.998636   0.981087  0.990453  0.985748
# 29        analysis    Naive Bayes  0.988749   0.808880  1.000000  0.894344
# 30       shellcode  Random Forest  0.998966   0.978723  1.000000  0.989247
# 31       shellcode        Bagging  0.999380   0.987124  1.000000  0.993521
# 32       shellcode            SGD  0.997725   0.954357  1.000000  0.976645
# 33       shellcode       AdaBoost  0.999586   0.995652  0.995652  0.995652
# 34       shellcode    Naive Bayes  0.996484   0.931174  1.000000  0.964361
# 35        backdoor  Random Forest  0.999731   0.997175  0.997175  0.997175
# 36        backdoor        Bagging  0.999060   0.988732  0.991525  0.990127
# 37        backdoor            SGD  0.995701   0.960000  0.949153  0.954545
# 38        backdoor       AdaBoost  0.998925   0.988701  0.988701  0.988701
# 39        backdoor    Naive Bayes  0.932554   0.411905  0.977401  0.579564
# 40             NaN  Random Forest  0.995149   0.984690  0.976472  0.980564
# 41             NaN        Bagging  0.995123   0.984343  0.976617  0.980465
# 42             NaN            SGD  0.988429   0.944612  0.964202  0.954307
# 43             NaN       AdaBoost  0.993078   0.975012  0.969614  0.972306
# 44             NaN    Naive Bayes  0.918642   0.608301  0.985086  0.752145
#
#     Train Time (s)  Test Time (s)             Type
# 0        12.897256       0.183120  Cross-Validated
# 1        57.040096       0.883976  Cross-Validated
# 2         0.854933       0.015472  Cross-Validated
# 3        28.015800       0.621970  Cross-Validated
# 4         0.193513       0.028073  Cross-Validated
# 5        17.563363       0.287568  Cross-Validated
# 6        87.488711       1.161755  Cross-Validated
# 7         1.033370       0.018827  Cross-Validated
# 8        42.179308       0.798152  Cross-Validated
# 9         0.230740       0.038714  Cross-Validated
# 10       38.239044       0.538612  Cross-Validated
# 11      174.213148       3.725917  Cross-Validated
# 12        2.163816       0.023240  Cross-Validated
# 13       91.463545       1.573513  Cross-Validated
# 14        0.505802       0.122595  Cross-Validated
# 15      138.328689       1.397124  Cross-Validated
# 16     1023.276608      10.841200  Cross-Validated
# 17        4.337734       0.041234  Cross-Validated
# 18      279.968952       4.578510  Cross-Validated
# 19        1.530620       0.362823  Cross-Validated
# 20       11.435866       0.163677  Cross-Validated
# 21       63.562457       0.821646  Cross-Validated
# 22        0.550849       0.018134  Cross-Validated
# 23       26.837892       0.589321  Cross-Validated
# 24        0.132277       0.025483  Cross-Validated
# 25        1.503331       0.036331  Cross-Validated
# 26        5.890953       0.108400  Cross-Validated
# 27        0.151631       0.002127  Cross-Validated
# 28        4.827506       0.131564  Cross-Validated
# 29        0.023578       0.006078  Cross-Validated
# 30        0.752348       0.022256  Cross-Validated
# 31        2.134771       0.068913  Cross-Validated
# 32        0.051921       0.001844  Cross-Validated
# 33        2.729032       0.094545  Cross-Validated
# 34        0.016916       0.003775  Cross-Validated
# 35        1.511724       0.036600  Cross-Validated
# 36        4.920230       0.097507  Cross-Validated
# 37        0.142745       0.002027  Cross-Validated
# 38        4.012146       0.121403  Cross-Validated
# 39        0.024970       0.006137  Cross-Validated
# 40      166.829685       2.456805     Full Dataset
# 41      773.520808      11.705309     Full Dataset
# 42        6.383645       0.043136     Full Dataset
# 43      359.140545       4.815724     Full Dataset
# 44        1.571517       0.375558     Full Dataset

# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind

# Configurazione
protocol = 'all'
results_path = '/gpuserver/caputo/keep_calm/GNN/results'
metrics = ['accuracy', 'f1_malicious', 'precision_malicious', 'recall_malicious']

# Caricamento CSV
ddp_files = glob.glob(f"{results_path}/ddp_training_results_{protocol}_*.csv")
single_files = glob.glob(f"{results_path}/training_results_{protocol}_*.csv")

def load_and_tag(files, mode):
    dfs = []
    for f in files:
        df = pd.read_csv(f)
        seed = f.split('_seed')[-1].replace('.csv', '')
        df['seed'] = seed
        df['mode'] = mode
        dfs.append(df)
    return pd.concat(dfs, ignore_index=True)

# Carica i dati
df_ddp = load_and_tag(ddp_files, 'ddp')
df_single = load_and_tag(single_files, 'single_gpu')
df_all = pd.concat([df_ddp, df_single], ignore_index=True)

# 📊 Statistiche medie
print("\n📊 Medie per categoria di attacco:")
summary = df_all.groupby(['attack_cat', 'mode'])[metrics].mean().round(4)
summary
# Out:
# 📊 Medie per categoria di attacco:
#                            accuracy  f1_malicious  precision_malicious  \
# attack_cat     mode
# analysis       ddp           0.9990        0.9895               0.9793
#                single_gpu    0.9986        0.9858               0.9744
# backdoor       ddp           0.9979        0.9788               0.9776
#                single_gpu    0.9981        0.9800               0.9860
# dos            ddp           0.9976        0.9751               0.9786
#                single_gpu    0.9979        0.9781               0.9835
# exploits       ddp           0.9968        0.9664               0.9547
#                single_gpu    0.9970        0.9687               0.9609
# full           ddp           0.9917        0.9668               0.9674
#                single_gpu    0.9917        0.9666               0.9709
# fuzzers        ddp           0.9882        0.8888               0.8086
#                single_gpu    0.9886        0.8921               0.8120
# generic        ddp           0.9994        0.9964               0.9989
#                single_gpu    0.9994        0.9968               0.9989
# reconnaissance ddp           0.9989        0.9885               0.9850
#                single_gpu    0.9995        0.9952               0.9944
# shellcode      ddp           0.9981        0.9802               0.9685
#                single_gpu    0.9984        0.9828               0.9703
#
#                            recall_malicious
# attack_cat     mode
# analysis       ddp                   1.0000
#                single_gpu            0.9976
# backdoor       ddp                   0.9801
#                single_gpu            0.9740
# dos            ddp                   0.9717
#                single_gpu            0.9728
# exploits       ddp                   0.9784
#                single_gpu            0.9768
# full           ddp                   0.9662
#                single_gpu            0.9623
# fuzzers        ddp                   0.9869
#                single_gpu            0.9897
# generic        ddp                   0.9939
#                single_gpu            0.9947
# reconnaissance ddp                   0.9921
#                single_gpu            0.9961
# shellcode      ddp                   0.9921
#                single_gpu            0.9956

# %%
# 🧪 T-test
print("\n🧪 Confronto statistico (t-test) per ogni attacco:")
for attack in df_all['attack_cat'].unique():
    print(f"\n🔎 Attacco: {attack.upper()}")
    df_attack = df_all[df_all['attack_cat'] == attack]
    for metric in metrics:
        vals_ddp = df_attack[df_attack['mode'] == 'ddp'][metric]
        vals_single = df_attack[df_attack['mode'] == 'single_gpu'][metric]
        if len(vals_ddp) >= 2 and len(vals_single) >= 2:
            stat, pval = ttest_ind(vals_single, vals_ddp, equal_var=False)
            print(f"{metric:22s} | p-value = {pval:.4f} {'(significativo)' if pval < 0.05 else ''}")
        else:
            print(f"{metric:22s} | Dati insufficienti per confronto")

# 📈 Boxplot per metrica e attacco
for metric in metrics:
    plt.figure(figsize=(12, 6))
    sns.boxplot(data=df_all, x='attack_cat', y=metric, hue='mode')
    plt.title(f'Boxplot {metric} per attacco (DDP vs Single GPU)')
    plt.xticks(rotation=45)
    plt.tight_layout()
    output_path = f"{results_path}/boxplot_{metric}_{protocol}.png"
    plt.savefig(output_path)
    print(f"📊 Salvato grafico: {output_path}")
    plt.close()
# Out:
# 🧪 Confronto statistico (t-test) per ogni attacco:
#
# 🔎 Attacco: FULL
# accuracy               | p-value = 0.7626
# f1_malicious           | p-value = 0.5327
# precision_malicious    | p-value = 0.0898
# recall_malicious       | p-value = 0.1163
#
# 🔎 Attacco: DOS
# accuracy               | p-value = 0.0049 (significativo)
# f1_malicious           | p-value = 0.0096 (significativo)
# precision_malicious    | p-value = 0.1318
# recall_malicious       | p-value = 0.6643
#
# 🔎 Attacco: FUZZERS
# accuracy               | p-value = 0.0175 (significativo)
# f1_malicious           | p-value = 0.0138 (significativo)
# precision_malicious    | p-value = 0.3214
# recall_malicious       | p-value = 0.5714
#
# 🔎 Attacco: EXPLOITS
# accuracy               | p-value = 0.0302 (significativo)
# f1_malicious           | p-value = 0.0215 (significativo)
# precision_malicious    | p-value = 0.2042
# recall_malicious       | p-value = 0.6336
#
# 🔎 Attacco: GENERIC
# accuracy               | p-value = 0.0256 (significativo)
# f1_malicious           | p-value = 0.0208 (significativo)
# precision_malicious    | p-value = 0.9717
# recall_malicious       | p-value = 0.0066 (significativo)
#
# 🔎 Attacco: RECONNAISSANCE
# accuracy               | p-value = 0.0026 (significativo)
# f1_malicious           | p-value = 0.0023 (significativo)
# precision_malicious    | p-value = 0.0055 (significativo)
# recall_malicious       | p-value = 0.1311
#
# 🔎 Attacco: ANALYSIS
# accuracy               | p-value = 0.0057 (significativo)
# f1_malicious           | p-value = 0.0032 (significativo)
# precision_malicious    | p-value = 0.0125 (significativo)
# recall_malicious       | p-value = 0.0000 (significativo)
#
# 🔎 Attacco: SHELLCODE
# accuracy               | p-value = 0.3637
# f1_malicious           | p-value = 0.3960
# precision_malicious    | p-value = 0.6455
# recall_malicious       | p-value = 0.2354
#
# 🔎 Attacco: BACKDOOR
# accuracy               | p-value = 0.4046
# f1_malicious           | p-value = 0.5836
# precision_malicious    | p-value = 0.1207
# recall_malicious       | p-value = 0.0473 (significativo)
# /gpuserver/caputo/miniconda3/envs/KC/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:573: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# 📊 Salvato grafico: /gpuserver/caputo/keep_calm/GNN/results/boxplot_accuracy_all.png
# 📊 Salvato grafico: /gpuserver/caputo/keep_calm/GNN/results/boxplot_f1_malicious_all.png
# 📊 Salvato grafico: /gpuserver/caputo/keep_calm/GNN/results/boxplot_precision_malicious_all.png
# 📊 Salvato grafico: /gpuserver/caputo/keep_calm/GNN/results/boxplot_recall_malicious_all.png
